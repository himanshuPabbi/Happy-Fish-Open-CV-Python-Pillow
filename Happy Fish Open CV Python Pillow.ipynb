# %%
# !pip3 install opencv-python pillow
# Out:
# Requirement already satisfied: opencv-python in c:\users\himan\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: pillow in c:\users\himan\anaconda3\lib\site-packages (9.4.0)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\himan\anaconda3\lib\site-packages (from opencv-python) (1.24.3)

# %%
import cv2
import numpy as np
from PIL import Image 
from IPython.display import Image as display

# %%
loc='HappyFish.jpg'
image = Image.open(loc)
print(image.size)
image1 = cv2.imread(loc)
cv2.imwrite(loc, image1)
display(filename=loc)
# Out:
# (259, 194)

# %%
img = cv2.imread(loc)
grayed = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(grayed)
cv2.imwrite(loc, grayed)
display(filename=loc)
# Out:
# [[254 254 254 ... 254 254 254]
#  [254 254 254 ... 254 254 254]
#  [254 254 254 ... 254 254 254]
#  ...
#  [254 254 254 ... 254 254 254]
#  [254 254 254 ... 254 254 254]
#  [254 254 254 ... 254 254 254]]

# %%
inverted = cv2.bitwise_not(grayed)
cv2.imwrite("inverted.jpg", inverted)
display(filename="inverted.jpg")

# %%
blurred = cv2.GaussianBlur(inverted, (15, 15), sigmaX=0, sigmaY=0)
cv2.imwrite("blurred.jpg", blurred)
display(filename="blurred.jpg")

# %%
def blend(x, y):
    return cv2.divide(x, 255 - y, scale=257)
final_result = blend(grayed, blurred)
cv2.imwrite("final.jpg", final_result)
display(filename="final.jpg")
